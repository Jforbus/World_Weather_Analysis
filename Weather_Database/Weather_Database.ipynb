# %%
# dependencies
import numpy as np
import requests
import pandas as pd
from citipy import citipy
from config import weather_api_key
import time

# %%
# create arrays of random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# join arrays in pairs. 
lat_lngs = zip(lats,lngs)

# create list from lat/lng pairs
coordinates = list(lat_lngs)

# %%
# create a list of random cities using citipy and generated random coordinates
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 738

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + 'lata'
c = requests.get(city_url).json()

# %%
# create list to hold data
city_data = []

# build api url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# initiate counters to track data retrieval and prevent API call limit timeout
record_count = 1
set_count = 1

# loop through list of cities, performing API call to collect data for each
for i, city in enumerate(cities):
    
    # group cities in sets of 50, pause after each set of 50 to allow call limit reset
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create url for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
     # log the url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    print(city_url)
    
     # add 1 to record count
    record_count += 1
    
    # run API request for each city
    try:
        
        city_weather = requests.get(city_url).json()
        # get data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]['description']
        
        # add city data to list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
        print('City Found')
    
    # if an error is experienced
    except:
        print('City not Found...Skipping')
        pass
    

print('Data Retrieval Complete')
# Out:
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hobart
# City Found
# Processing Record 2 of Set 1 | boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=boende
# City Found
# Processing Record 3 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=vaini
# City Found
# Processing Record 4 of Set 1 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=caravelas
# City Found
# Processing Record 5 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=rikitea
# City Found
# Processing Record 6 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=port+alfred
# City Found
# Processing Record 7 of Set 1 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=prince+rupert
# City Found
# Processing Record 8 of Set 1 | minervino murge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=minervino+murge
# City Found
# Processing Record 9 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=castro
# City Found
# Processing Record 10 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kapaa
# City Found
# Processing Record 11 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mataura
# City Found
# Processing Record 12 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=punta+arenas
# City Found
# Processing Record 13 of Set 1 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=haines+junction
# City Found
# Processing Record 14 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=attawapiskat
# City not Found...Skipping
# Processing Record 15 of Set 1 | algeciras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=algeciras
# City Found
# Processing Record 16 of Set 1 | sarahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sarahan
# City Found
# Processing Record 17 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bluff
# City Found
# Processing Record 18 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=barrow
# City Found
# Processing Record 19 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=busselton
# City Found
# Processing Record 20 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=saskylakh
# City Found
# Processing Record 21 of Set 1 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bubaque
# City Found
# Processing Record 22 of Set 1 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=emerald
# City Found
# Processing Record 23 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ushuaia
# City Found
# Processing Record 24 of Set 1 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pangody
# City Found
# Processing Record 25 of Set 1 | cervo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cervo
# City Found
# Processing Record 26 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hithadhoo
# City Found
# Processing Record 27 of Set 1 | hihifo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hihifo
# City not Found...Skipping
# Processing Record 28 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=albany
# City Found
# Processing Record 29 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=avarua
# City Found
# Processing Record 30 of Set 1 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=port+hedland
# City Found
# Processing Record 31 of Set 1 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=vardo
# City Found
# Processing Record 32 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=klaksvik
# City Found
# Processing Record 33 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cherskiy
# City Found
# Processing Record 34 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=saldanha
# City Found
# Processing Record 35 of Set 1 | aki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=aki
# City Found
# Processing Record 36 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=qaanaaq
# City Found
# Processing Record 37 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chokurdakh
# City Found
# Processing Record 38 of Set 1 | toora-khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=toora-khem
# City Found
# Processing Record 39 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kruisfontein
# City Found
# Processing Record 40 of Set 1 | vredendal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=vredendal
# City Found
# Processing Record 41 of Set 1 | bernissart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bernissart
# City Found
# Processing Record 42 of Set 1 | dickinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dickinson
# City Found
# Processing Record 43 of Set 1 | mizdah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mizdah
# City Found
# Processing Record 44 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tuktoyaktuk
# City Found
# Processing Record 45 of Set 1 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lokosovo
# City Found
# Processing Record 46 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=faanui
# City Found
# Processing Record 47 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=yulara
# City Found
# Processing Record 48 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=leningradskiy
# City Found
# Processing Record 49 of Set 1 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=atar
# City Found
# Processing Record 50 of Set 1 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=stornoway
# City Found
# Processing Record 1 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=illoqqortoormiut
# City not Found...Skipping
# Processing Record 2 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=san+patricio
# City Found
# Processing Record 3 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=narsaq
# City Found
# Processing Record 4 of Set 2 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=isangel
# City Found
# Processing Record 5 of Set 2 | urzhum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=urzhum
# City Found
# Processing Record 6 of Set 2 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=laguna
# City Found
# Processing Record 7 of Set 2 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=houma
# City Found
# Processing Record 8 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mahebourg
# City Found
# Processing Record 9 of Set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=esperance
# City Found
# Processing Record 10 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=thompson
# City Found
# Processing Record 11 of Set 2 | paraje nuevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=paraje+nuevo
# City Found
# Processing Record 12 of Set 2 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=derzhavinsk
# City Found
# Processing Record 13 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kodiak
# City Found
# Processing Record 14 of Set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dunedin
# City Found
# Processing Record 15 of Set 2 | pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pontianak
# City Found
# Processing Record 16 of Set 2 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=geraldton
# City Found
# Processing Record 17 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tasiilaq
# City Found
# Processing Record 18 of Set 2 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hualmay
# City Found
# Processing Record 19 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=saint-philippe
# City Found
# Processing Record 20 of Set 2 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=richards+bay
# City Found
# Processing Record 21 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=new+norfolk
# City Found
# Processing Record 22 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=torbay
# City Found
# Processing Record 23 of Set 2 | svay rieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=svay+rieng
# City Found
# Processing Record 24 of Set 2 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lagoa
# City Found
# Processing Record 25 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hermanus
# City Found
# Processing Record 26 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=jamestown
# City Found
# Processing Record 27 of Set 2 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=grindavik
# City Found
# Processing Record 28 of Set 2 | kehtna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kehtna
# City Found
# Processing Record 29 of Set 2 | kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kamaishi
# City Found
# Processing Record 30 of Set 2 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=flinders
# City Found
# Processing Record 31 of Set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ancud
# City Found
# Processing Record 32 of Set 2 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=codrington
# City Found
# Processing Record 33 of Set 2 | cercal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cercal
# City Found
# Processing Record 34 of Set 2 | guane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=guane
# City Found
# Processing Record 35 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bambous+virieux
# City Found
# Processing Record 36 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nikolskoye
# City Found
# Processing Record 37 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=saint+george
# City Found
# Processing Record 38 of Set 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=butaritari
# City Found
# Processing Record 39 of Set 2 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=berlevag
# City Found
# Processing Record 40 of Set 2 | warrnambool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=warrnambool
# City Found
# Processing Record 41 of Set 2 | hailey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hailey
# City Found
# Processing Record 42 of Set 2 | furano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=furano
# City Found
# Processing Record 43 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cape+town
# City Found
# Processing Record 44 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=atuona
# City Found
# Processing Record 45 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=taolanaro
# City not Found...Skipping
# Processing Record 46 of Set 2 | sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sungairaya
# City Found
# Processing Record 47 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=norman+wells
# City Found
# Processing Record 48 of Set 2 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kikwit
# City Found
# Processing Record 49 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=georgetown
# City Found
# Processing Record 50 of Set 2 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=belushya+guba
# City not Found...Skipping
# Processing Record 1 of Set 3 | llanes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=llanes
# City Found
# Processing Record 2 of Set 3 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mareeba
# City Found
# Processing Record 3 of Set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bengkulu
# City Found
# Processing Record 4 of Set 3 | chimbarongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chimbarongo
# City Found
# Processing Record 5 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dikson
# City Found
# Processing Record 6 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bredasdorp
# City Found
# Processing Record 7 of Set 3 | baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=baghdad
# City Found
# Processing Record 8 of Set 3 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tabiauea
# City not Found...Skipping
# Processing Record 9 of Set 3 | taburi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=taburi
# City not Found...Skipping
# Processing Record 10 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=provideniya
# City Found
# Processing Record 11 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=adrar
# City Found
# Processing Record 12 of Set 3 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=rawson
# City Found
# Processing Record 13 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=yellowknife
# City Found
# Processing Record 14 of Set 3 | diebougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=diebougou
# City Found
# Processing Record 15 of Set 3 | wahpeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=wahpeton
# City Found
# Processing Record 16 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lompoc
# City Found
# Processing Record 17 of Set 3 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=akdepe
# City Found
# Processing Record 18 of Set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hilo
# City Found
# Processing Record 19 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=puerto+ayora
# City Found
# Processing Record 20 of Set 3 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=namatanai
# City Found
# Processing Record 21 of Set 3 | pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pingliang
# City Found
# Processing Record 22 of Set 3 | dunyapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dunyapur
# City Found
# Processing Record 23 of Set 3 | tsybli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tsybli
# City Found
# Processing Record 24 of Set 3 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=santa+maria
# City Found
# Processing Record 25 of Set 3 | puqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=puqi
# City Found
# Processing Record 26 of Set 3 | krasnoznamensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=krasnoznamensk
# City Found
# Processing Record 27 of Set 3 | saint stephen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=saint+stephen
# City Found
# Processing Record 28 of Set 3 | baie-comeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=baie-comeau
# City Found
# Processing Record 29 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kavieng
# City Found
# Processing Record 30 of Set 3 | camargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=camargo
# City Found
# Processing Record 31 of Set 3 | donskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=donskoye
# City Found
# Processing Record 32 of Set 3 | mandurah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mandurah
# City Found
# Processing Record 33 of Set 3 | piotrkow trybunalski
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=piotrkow+trybunalski
# City Found
# Processing Record 34 of Set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=fortuna
# City Found
# Processing Record 35 of Set 3 | galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=galle
# City Found
# Processing Record 36 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=longyearbyen
# City Found
# Processing Record 37 of Set 3 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=aksu
# City Found
# Processing Record 38 of Set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=salalah
# City Found
# Processing Record 39 of Set 3 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=barentsburg
# City not Found...Skipping
# Processing Record 40 of Set 3 | poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=poya
# City Found
# Processing Record 41 of Set 3 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chernyshevskiy
# City Found
# Processing Record 42 of Set 3 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=samarai
# City Found
# Processing Record 43 of Set 3 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lasa
# City Found
# Processing Record 44 of Set 3 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=zhuhai
# City Found
# Processing Record 45 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=khatanga
# City Found
# Processing Record 46 of Set 3 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=rio+gallegos
# City Found
# Processing Record 47 of Set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tiksi
# City Found
# Processing Record 48 of Set 3 | khuzhir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=khuzhir
# City Found
# Processing Record 49 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=victoria
# City Found
# Processing Record 50 of Set 3 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=qaqortoq
# City Found
# Processing Record 1 of Set 4 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=namibe
# City Found
# Processing Record 2 of Set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nouadhibou
# City Found
# Processing Record 3 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ponta+do+sol
# City Found
# Processing Record 4 of Set 4 | am timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=am+timan
# City Found
# Processing Record 5 of Set 4 | gourcy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=gourcy
# City Found
# Processing Record 6 of Set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cayenne
# City Found
# Processing Record 7 of Set 4 | goma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=goma
# City Found
# Processing Record 8 of Set 4 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kavaratti
# City Found
# Processing Record 9 of Set 4 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=araouane
# City Found
# Processing Record 10 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chuy
# City Found
# Processing Record 11 of Set 4 | putina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=putina
# City Found
# Processing Record 12 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mar+del+plata
# City Found
# Processing Record 13 of Set 4 | mancio lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mancio+lima
# City Found
# Processing Record 14 of Set 4 | malindi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=malindi
# City Found
# Processing Record 15 of Set 4 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=quatre+cocos
# City Found
# Processing Record 16 of Set 4 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=gat
# City Found
# Processing Record 17 of Set 4 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=yeppoon
# City Found
# Processing Record 18 of Set 4 | trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=trinidad
# City Found
# Processing Record 19 of Set 4 | brownsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=brownsville
# City Found
# Processing Record 20 of Set 4 | hirado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hirado
# City Found
# Processing Record 21 of Set 4 | langsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=langsa
# City Found
# Processing Record 22 of Set 4 | bad mergentheim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bad+mergentheim
# City Found
# Processing Record 23 of Set 4 | pariquera-acu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pariquera-acu
# City not Found...Skipping
# Processing Record 24 of Set 4 | fredericton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=fredericton
# City Found
# Processing Record 25 of Set 4 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pevek
# City Found
# Processing Record 26 of Set 4 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sao+filipe
# City Found
# Processing Record 27 of Set 4 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=comodoro+rivadavia
# City Found
# Processing Record 28 of Set 4 | chupei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chupei
# City not Found...Skipping
# Processing Record 29 of Set 4 | sheltozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sheltozero
# City Found
# Processing Record 30 of Set 4 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=maceio
# City Found
# Processing Record 31 of Set 4 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=san+juan
# City Found
# Processing Record 32 of Set 4 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=seoul
# City Found
# Processing Record 33 of Set 4 | bani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bani
# City Found
# Processing Record 34 of Set 4 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=port+blair
# City Found
# Processing Record 35 of Set 4 | kyren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kyren
# City Found
# Processing Record 36 of Set 4 | mossendjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mossendjo
# City Found
# Processing Record 37 of Set 4 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tsihombe
# City not Found...Skipping
# Processing Record 38 of Set 4 | bulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bulgan
# City Found
# Processing Record 39 of Set 4 | petatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=petatlan
# City Found
# Processing Record 40 of Set 4 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=saleaula
# City not Found...Skipping
# Processing Record 41 of Set 4 | kozhva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kozhva
# City Found
# Processing Record 42 of Set 4 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sentyabrskiy
# City not Found...Skipping
# Processing Record 43 of Set 4 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mecca
# City Found
# Processing Record 44 of Set 4 | jabiru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=jabiru
# City not Found...Skipping
# Processing Record 45 of Set 4 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=okhotsk
# City Found
# Processing Record 46 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lebu
# City Found
# Processing Record 47 of Set 4 | marovoay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=marovoay
# City Found
# Processing Record 48 of Set 4 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mount+gambier
# City Found
# Processing Record 49 of Set 4 | gobabis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=gobabis
# City Found
# Processing Record 50 of Set 4 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=half+moon+bay
# City Found
# Processing Record 1 of Set 5 | luancheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=luancheng
# City Found
# Processing Record 2 of Set 5 | ordu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ordu
# City Found
# Processing Record 3 of Set 5 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=palmer
# City Found
# Processing Record 4 of Set 5 | solovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=solovetskiy
# City not Found...Skipping
# Processing Record 5 of Set 5 | creel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=creel
# City Found
# Processing Record 6 of Set 5 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=udachnyy
# City Found
# Processing Record 7 of Set 5 | coffs harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=coffs+harbour
# City Found
# Processing Record 8 of Set 5 | del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=del+rio
# City Found
# Processing Record 9 of Set 5 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=acapulco
# City Found
# Processing Record 10 of Set 5 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cidreira
# City Found
# Processing Record 11 of Set 5 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mehamn
# City Found
# Processing Record 12 of Set 5 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=omsukchan
# City Found
# Processing Record 13 of Set 5 | bousso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bousso
# City Found
# Processing Record 14 of Set 5 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=fukue
# City Found
# Processing Record 15 of Set 5 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=champerico
# City Found
# Processing Record 16 of Set 5 | cape coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cape+coast
# City Found
# Processing Record 17 of Set 5 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=aklavik
# City Found
# Processing Record 18 of Set 5 | camapua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=camapua
# City Found
# Processing Record 19 of Set 5 | uthal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=uthal
# City Found
# Processing Record 20 of Set 5 | sinop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sinop
# City Found
# Processing Record 21 of Set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nanortalik
# City Found
# Processing Record 22 of Set 5 | svilajnac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=svilajnac
# City Found
# Processing Record 23 of Set 5 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=upernavik
# City Found
# Processing Record 24 of Set 5 | chongoyape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chongoyape
# City Found
# Processing Record 25 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=port+elizabeth
# City Found
# Processing Record 26 of Set 5 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=vostok
# City Found
# Processing Record 27 of Set 5 | apricena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=apricena
# City Found
# Processing Record 28 of Set 5 | basoko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=basoko
# City Found
# Processing Record 29 of Set 5 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=portland
# City Found
# Processing Record 30 of Set 5 | simao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=simao
# City Found
# Processing Record 31 of Set 5 | ishikari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ishikari
# City Found
# Processing Record 32 of Set 5 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=asau
# City Found
# Processing Record 33 of Set 5 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=vanimo
# City Found
# Processing Record 34 of Set 5 | nykoping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nykoping
# City Found
# Processing Record 35 of Set 5 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=faya
# City Found
# Processing Record 36 of Set 5 | haapiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=haapiti
# City Found
# Processing Record 37 of Set 5 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sorvag
# City not Found...Skipping
# Processing Record 38 of Set 5 | teluk nibung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=teluk+nibung
# City Found
# Processing Record 39 of Set 5 | boca del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=boca+del+rio
# City Found
# Processing Record 40 of Set 5 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=moose+factory
# City Found
# Processing Record 41 of Set 5 | maarianhamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=maarianhamina
# City Found
# Processing Record 42 of Set 5 | newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=newport
# City Found
# Processing Record 43 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=airai
# City Found
# Processing Record 44 of Set 5 | bandrele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bandrele
# City Found
# Processing Record 45 of Set 5 | chapleau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chapleau
# City Found
# Processing Record 46 of Set 5 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sakaiminato
# City Found
# Processing Record 47 of Set 5 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bethel
# City Found
# Processing Record 48 of Set 5 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dingle
# City Found
# Processing Record 49 of Set 5 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=grand+river+south+east
# City not Found...Skipping
# Processing Record 50 of Set 5 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=christchurch
# City Found
# Processing Record 1 of Set 6 | fredericksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=fredericksburg
# City Found
# Processing Record 2 of Set 6 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sao+joao+da+barra
# City Found
# Processing Record 3 of Set 6 | raton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=raton
# City Found
# Processing Record 4 of Set 6 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=aflu
# City not Found...Skipping
# Processing Record 5 of Set 6 | sedelnikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sedelnikovo
# City not Found...Skipping
# Processing Record 6 of Set 6 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=honiara
# City Found
# Processing Record 7 of Set 6 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kahului
# City Found
# Processing Record 8 of Set 6 | pudem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pudem
# City Found
# Processing Record 9 of Set 6 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nantucket
# City Found
# Processing Record 10 of Set 6 | saucillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=saucillo
# City Found
# Processing Record 11 of Set 6 | rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=rosarito
# City Found
# Processing Record 12 of Set 6 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=havre-saint-pierre
# City Found
# Processing Record 13 of Set 6 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lorengau
# City Found
# Processing Record 14 of Set 6 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=progreso
# City Found
# Processing Record 15 of Set 6 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=solnechnyy
# City Found
# Processing Record 16 of Set 6 | lillooet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lillooet
# City Found
# Processing Record 17 of Set 6 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cabo+san+lucas
# City Found
# Processing Record 18 of Set 6 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=zhigansk
# City Found
# Processing Record 19 of Set 6 | skiros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=skiros
# City not Found...Skipping
# Processing Record 20 of Set 6 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=coquimbo
# City Found
# Processing Record 21 of Set 6 | ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ostersund
# City Found
# Processing Record 22 of Set 6 | marshall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=marshall
# City Found
# Processing Record 23 of Set 6 | outjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=outjo
# City Found
# Processing Record 24 of Set 6 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=borogontsy
# City Found
# Processing Record 25 of Set 6 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=katsuura
# City Found
# Processing Record 26 of Set 6 | scottsbluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=scottsbluff
# City Found
# Processing Record 27 of Set 6 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tuatapere
# City Found
# Processing Record 28 of Set 6 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=camacha
# City Found
# Processing Record 29 of Set 6 | ballitoville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ballitoville
# City Found
# Processing Record 30 of Set 6 | dargaville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dargaville
# City Found
# Processing Record 31 of Set 6 | cumaribo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cumaribo
# City not Found...Skipping
# Processing Record 32 of Set 6 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ribeira+grande
# City Found
# Processing Record 33 of Set 6 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sibu
# City Found
# Processing Record 34 of Set 6 | mudgee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mudgee
# City Found
# Processing Record 35 of Set 6 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=vestmannaeyjar
# City Found
# Processing Record 36 of Set 6 | loding
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=loding
# City Found
# Processing Record 37 of Set 6 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bilibino
# City Found
# Processing Record 38 of Set 6 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=esmeraldas
# City Found
# Processing Record 39 of Set 6 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kokopo
# City Found
# Processing Record 40 of Set 6 | aitape
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=manokwari
# City Found
# Processing Record 44 of Set 13 | hounde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=hounde
# City Found
# Processing Record 45 of Set 13 | kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kuching
# City Found
# Processing Record 46 of Set 13 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=isla+mujeres
# City Found
# Processing Record 47 of Set 13 | santo domingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=santo+domingo
# City Found
# Processing Record 48 of Set 13 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tautira
# City Found
# Processing Record 49 of Set 13 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=yerbogachen
# City Found
# Processing Record 50 of Set 13 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ushtobe
# City Found
# Processing Record 1 of Set 14 | narasannapeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=narasannapeta
# City Found
# Processing Record 2 of Set 14 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=gizo
# City Found
# Processing Record 3 of Set 14 | thayetmyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=thayetmyo
# City Found
# Processing Record 4 of Set 14 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=alihe
# City Found
# Processing Record 5 of Set 14 | sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sumbe
# City Found
# Processing Record 6 of Set 14 | teguldet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=teguldet
# City Found
# Processing Record 7 of Set 14 | high rock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=high+rock
# City Found
# Processing Record 8 of Set 14 | linchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=linchuan
# City not Found...Skipping
# Processing Record 9 of Set 14 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=berdigestyakh
# City Found
# Processing Record 10 of Set 14 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=taltal
# City Found
# Processing Record 11 of Set 14 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sorland
# City Found
# Processing Record 12 of Set 14 | chingirlau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chingirlau
# City Found
# Processing Record 13 of Set 14 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nome
# City Found
# Processing Record 14 of Set 14 | akureyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=akureyri
# City Found
# Processing Record 15 of Set 14 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=padang
# City Found
# Processing Record 16 of Set 14 | gazli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=gazli
# City Found
# Processing Record 17 of Set 14 | cameta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cameta
# City Found
# Processing Record 18 of Set 14 | kolda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kolda
# City Found
# Processing Record 19 of Set 14 | nautla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nautla
# City Found
# Processing Record 20 of Set 14 | dryden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dryden
# City Found
# Processing Record 21 of Set 14 | pinerovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pinerovka
# City Found
# Processing Record 22 of Set 14 | bantry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bantry
# City Found
# Processing Record 23 of Set 14 | waitati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=waitati
# City Found
# Processing Record 24 of Set 14 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ketchikan
# City Found
# Processing Record 25 of Set 14 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=cabedelo
# City Found
# Processing Record 26 of Set 14 | socastee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=socastee
# City Found
# Processing Record 27 of Set 14 | conceicao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=conceicao+da+barra
# City Found
# Processing Record 28 of Set 14 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=srednekolymsk
# City Found
# Processing Record 29 of Set 14 | nikopol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nikopol
# City Found
# Processing Record 30 of Set 14 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=waingapu
# City Found
# Processing Record 31 of Set 14 | liuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=liuli
# City Found
# Processing Record 32 of Set 14 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sept-iles
# City Found
# Processing Record 33 of Set 14 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=westport
# City Found
# Processing Record 34 of Set 14 | great falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=great+falls
# City Found
# Processing Record 35 of Set 14 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ilulissat
# City Found
# Processing Record 36 of Set 14 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=axim
# City Found
# Processing Record 37 of Set 14 | bolshegrivskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bolshegrivskoye
# City not Found...Skipping
# Processing Record 38 of Set 14 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nemuro
# City Found
# Processing Record 39 of Set 14 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=flin+flon
# City Found
# Processing Record 40 of Set 14 | azimur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=azimur
# City not Found...Skipping
# Processing Record 41 of Set 14 | thai binh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=thai+binh
# City Found
# Processing Record 42 of Set 14 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=innisfail
# City Found
# Processing Record 43 of Set 14 | pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=pedernales
# City Found
# Processing Record 44 of Set 14 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=upata
# City Found
# Processing Record 45 of Set 14 | caborca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=caborca
# City Found
# Processing Record 46 of Set 14 | tres lagoas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tres+lagoas
# City Found
# Processing Record 47 of Set 14 | adre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=adre
# City Found
# Processing Record 48 of Set 14 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=egvekinot
# City Found
# Processing Record 49 of Set 14 | moletai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=moletai
# City Found
# Processing Record 50 of Set 14 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bambanglipuro
# City Found
# Processing Record 1 of Set 15 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=presidencia+roque+saenz+pena
# City Found
# Processing Record 2 of Set 15 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=dudinka
# City Found
# Processing Record 3 of Set 15 | kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kendari
# City Found
# Processing Record 4 of Set 15 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=daru
# City Found
# Processing Record 5 of Set 15 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=bur+gabo
# City not Found...Skipping
# Processing Record 6 of Set 15 | sheregesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=sheregesh
# City Found
# Processing Record 7 of Set 15 | aras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=aras
# City Found
# Processing Record 8 of Set 15 | lukaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lukaya
# City Found
# Processing Record 9 of Set 15 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=abu+kamal
# City Found
# Processing Record 10 of Set 15 | nagorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=nagorsk
# City Found
# Processing Record 11 of Set 15 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=soyo
# City Found
# Processing Record 12 of Set 15 | kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kautokeino
# City Found
# Processing Record 13 of Set 15 | caruray
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=caruray
# City Found
# Processing Record 14 of Set 15 | mazabuka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mazabuka
# City Found
# Processing Record 15 of Set 15 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=celestun
# City Found
# Processing Record 16 of Set 15 | lumeje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=lumeje
# City Found
# Processing Record 17 of Set 15 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ucluelet
# City Found
# Processing Record 18 of Set 15 | safwah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=safwah
# City not Found...Skipping
# Processing Record 19 of Set 15 | mufumbwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mufumbwe
# City Found
# Processing Record 20 of Set 15 | chesterton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=chesterton
# City Found
# Processing Record 21 of Set 15 | ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=ajdabiya
# City Found
# Processing Record 22 of Set 15 | tete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=tete
# City Found
# Processing Record 23 of Set 15 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=mabaruma
# City Found
# Processing Record 24 of Set 15 | kalomo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kalomo
# City not Found...Skipping
# Processing Record 25 of Set 15 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=whitehorse
# City Found
# Processing Record 26 of Set 15 | alnashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=alnashi
# City Found
# Processing Record 27 of Set 15 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=san+cristobal
# City Found
# Processing Record 28 of Set 15 | yanchukan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=yanchukan
# City not Found...Skipping
# Processing Record 29 of Set 15 | huanren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=huanren
# City Found
# Processing Record 30 of Set 15 | seara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=seara
# City Found
# Processing Record 31 of Set 15 | kusye-aleksandrovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kusye-aleksandrovskiy
# City not Found...Skipping
# Processing Record 32 of Set 15 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=matara
# City Found
# Processing Record 33 of Set 15 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=beringovskiy
# City Found
# Processing Record 34 of Set 15 | manbij
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=manbij
# City Found
# Processing Record 35 of Set 15 | namuac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=namuac
# City Found
# Processing Record 36 of Set 15 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=umzimvubu
# City not Found...Skipping
# Processing Record 37 of Set 15 | kosh-agach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=kosh-agach
# City Found
# Processing Record 38 of Set 15 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24df4ffc318cfe0817a5fecfd42142b3&q=vanavara
# City Found
# Data Retrieval Complete

# %%
len(city_data)
# Out:
# 664

# %%
# created dataframe from city data
weather_df = pd.DataFrame(city_data)

weather_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hobart -42.8794  147.3294     46.26        69          40
# 1           Boende  -0.2167   20.8667     68.43        99          83
# 2            Vaini -21.2000 -175.2000     80.76        74          20
# 3        Caravelas -17.7125  -39.2481     69.84        77           8
# 4          Rikitea -23.1203 -134.9692     73.13        73           3
# 5      Port Alfred -33.5906   26.8910     56.17        92          99
# 6    Prince Rupert  54.3161 -130.3201     62.69        70           0
# 7  Minervino Murge  41.0843   16.0784     64.24        69          20
# 8           Castro -24.7911  -50.0119     54.82        98          98
# 9            Kapaa  22.0752 -159.3190     84.18        78         100
#
#    Wind Speed Country Current Description
# 0       12.66      AU    scattered clouds
# 1        1.86      CD       broken clouds
# 2        8.05      TO          few clouds
# 3        3.98      BR           clear sky
# 4        5.41      PF           clear sky
# 5       15.88      ZA          light rain
# 6        8.05      CA           clear sky
# 7        8.99      IT          few clouds
# 8        7.65      BR     overcast clouds
# 9        3.44      US          light rain

# %%
# rearrange Dataframe

column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Current Description']
weather_df = weather_df[column_order]
weather_df.sample(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 452  Komsomolskiy      UZ  40.4272   71.7189     63.32        48          63
# 178        Kozhva      RU  65.1073   57.0459     42.60        97          99
# 651          Tete      MZ -16.1564   33.5867     73.80        45           0
# 308     Tchollire      CM   8.4022   14.1698     70.90        94         100
# 217        Vanimo      PG  -2.6741  141.3028     83.57        67          97
# 18      Saskylakh      RU  71.9167  114.0833     33.78        80          90
# 95         Llanes      ES  43.4198   -4.7549     72.97        67          69
# 184       Gobabis      NA -22.4500   18.9667     64.92        14           0
# 324       Husavik      IS  66.0449  -17.3389     47.34        94         100
# 87         Hailey      US  43.5196 -114.3153     86.88        24           0
#
#     Current Description
# 452       broken clouds
# 178     overcast clouds
# 651           clear sky
# 308     overcast clouds
# 217     overcast clouds
# 18      overcast clouds
# 95        broken clouds
# 184           clear sky
# 324     overcast clouds
# 87                smoke

# %%
# export dataframe as csv
# create output file
output_data_file = 'WeatherPy_Database.csv'

# export dataframe to file
weather_df.to_csv(output_data_file, index_label='City_ID')
