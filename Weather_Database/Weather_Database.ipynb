# %%
# dependencies
import numpy as np
import requests
import pandas as pd
from citipy import citipy
from config import weather_api_key
import time

# %%
# create arrays of random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# join arrays in pairs. 
lat_lngs = zip(lats,lngs)

# create list from lat/lng pairs
coordinates = list(lat_lngs)

# %%
# create a list of random cities using citipy and generated random coordinates
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 763

# %%
# create list to hold data
city_data = []

# build api url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# initiate counters to track data retrieval and prevent API call limit timeout
record_count = 1
set_count = 1

# loop through list of cities, performing API call to collect data for each
for i, city in enumerate(cities):
    
    # group cities in sets of 50, pause after each set of 50 to allow call limit reset
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create url for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
     # log the url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    
     # add 1 to record count
    record_count += 1
    
    # run API request for each city
    try:
        
        city_weather = requests.get(city_url).json()
        # get data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]['description']
        
        # add city data to list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
        print('City Found')
    
    # if an error is experienced
    except:
        print('City not Found...Skipping')
        pass
    

print('Data Retrieval Complete')
# Out:
# Processing Record 1 of Set 1 | vaini
# City Found
# Processing Record 2 of Set 1 | hermanus
# City Found
# Processing Record 3 of Set 1 | hilo
# City Found
# Processing Record 4 of Set 1 | constantine
# City Found
# Processing Record 5 of Set 1 | slave lake
# City Found
# Processing Record 6 of Set 1 | mar del plata
# City Found
# Processing Record 7 of Set 1 | saint-augustin
# City Found
# Processing Record 8 of Set 1 | makakilo city
# City Found
# Processing Record 9 of Set 1 | chuy
# City Found
# Processing Record 10 of Set 1 | cape town
# City Found
# Processing Record 11 of Set 1 | ndioum
# City Found
# Processing Record 12 of Set 1 | rikitea
# City Found
# Processing Record 13 of Set 1 | hithadhoo
# City Found
# Processing Record 14 of Set 1 | aneho
# City Found
# Processing Record 15 of Set 1 | vardo
# City Found
# Processing Record 16 of Set 1 | kokorevka
# City Found
# Processing Record 17 of Set 1 | ushuaia
# City Found
# Processing Record 18 of Set 1 | yamada
# City Found
# Processing Record 19 of Set 1 | saint george
# City Found
# Processing Record 20 of Set 1 | biak
# City Found
# Processing Record 21 of Set 1 | bredasdorp
# City Found
# Processing Record 22 of Set 1 | tsihombe
# City not Found...Skipping
# Processing Record 23 of Set 1 | chokurdakh
# City Found
# Processing Record 24 of Set 1 | kodiak
# City Found
# Processing Record 25 of Set 1 | sitio novo do tocantins
# City Found
# Processing Record 26 of Set 1 | bluff
# City Found
# Processing Record 27 of Set 1 | hobart
# City Found
# Processing Record 28 of Set 1 | ketchikan
# City Found
# Processing Record 29 of Set 1 | azogues
# City Found
# Processing Record 30 of Set 1 | ilulissat
# City Found
# Processing Record 31 of Set 1 | barrow
# City Found
# Processing Record 32 of Set 1 | thompson
# City Found
# Processing Record 33 of Set 1 | avarua
# City Found
# Processing Record 34 of Set 1 | punta arenas
# City Found
# Processing Record 35 of Set 1 | yellowknife
# City Found
# Processing Record 36 of Set 1 | mehran
# City Found
# Processing Record 37 of Set 1 | requena
# City Found
# Processing Record 38 of Set 1 | lazaro cardenas
# City Found
# Processing Record 39 of Set 1 | horta
# City Found
# Processing Record 40 of Set 1 | mataura
# City Found
# Processing Record 41 of Set 1 | adrar
# City Found
# Processing Record 42 of Set 1 | port elizabeth
# City Found
# Processing Record 43 of Set 1 | upernavik
# City Found
# Processing Record 44 of Set 1 | nefteyugansk
# City Found
# Processing Record 45 of Set 1 | cabo san lucas
# City Found
# Processing Record 46 of Set 1 | guerrero negro
# City Found
# Processing Record 47 of Set 1 | itaituba
# City Found
# Processing Record 48 of Set 1 | port alfred
# City Found
# Processing Record 49 of Set 1 | halalo
# City not Found...Skipping
# Processing Record 50 of Set 1 | armizonskoye
# City Found
# Processing Record 1 of Set 2 | batemans bay
# City Found
# Processing Record 2 of Set 2 | zhezkazgan
# City Found
# Processing Record 3 of Set 2 | taolanaro
# City not Found...Skipping
# Processing Record 4 of Set 2 | airai
# City Found
# Processing Record 5 of Set 2 | padang
# City Found
# Processing Record 6 of Set 2 | rocha
# City Found
# Processing Record 7 of Set 2 | dillon
# City Found
# Processing Record 8 of Set 2 | catamarca
# City Found
# Processing Record 9 of Set 2 | amderma
# City not Found...Skipping
# Processing Record 10 of Set 2 | port hueneme
# City Found
# Processing Record 11 of Set 2 | orito
# City Found
# Processing Record 12 of Set 2 | bethel
# City Found
# Processing Record 13 of Set 2 | ca mau
# City Found
# Processing Record 14 of Set 2 | vila velha
# City Found
# Processing Record 15 of Set 2 | belushya guba
# City not Found...Skipping
# Processing Record 16 of Set 2 | dakar
# City Found
# Processing Record 17 of Set 2 | ippy
# City Found
# Processing Record 18 of Set 2 | abu dhabi
# City Found
# Processing Record 19 of Set 2 | busselton
# City Found
# Processing Record 20 of Set 2 | albany
# City Found
# Processing Record 21 of Set 2 | castro
# City Found
# Processing Record 22 of Set 2 | tura
# City Found
# Processing Record 23 of Set 2 | sindor
# City Found
# Processing Record 24 of Set 2 | ballina
# City Found
# Processing Record 25 of Set 2 | tiksi
# City Found
# Processing Record 26 of Set 2 | eskasem
# City not Found...Skipping
# Processing Record 27 of Set 2 | tasiilaq
# City Found
# Processing Record 28 of Set 2 | torbay
# City Found
# Processing Record 29 of Set 2 | tunduru
# City not Found...Skipping
# Processing Record 30 of Set 2 | pisco
# City Found
# Processing Record 31 of Set 2 | karaul
# City not Found...Skipping
# Processing Record 32 of Set 2 | aquiraz
# City Found
# Processing Record 33 of Set 2 | puerto leguizamo
# City Found
# Processing Record 34 of Set 2 | meyungs
# City not Found...Skipping
# Processing Record 35 of Set 2 | orgun
# City not Found...Skipping
# Processing Record 36 of Set 2 | ahipara
# City Found
# Processing Record 37 of Set 2 | samusu
# City not Found...Skipping
# Processing Record 38 of Set 2 | tabulbah
# City not Found...Skipping
# Processing Record 39 of Set 2 | sobolevo
# City Found
# Processing Record 40 of Set 2 | attawapiskat
# City not Found...Skipping
# Processing Record 41 of Set 2 | khatanga
# City Found
# Processing Record 42 of Set 2 | cheremkhovo
# City Found
# Processing Record 43 of Set 2 | huarmey
# City Found
# Processing Record 44 of Set 2 | barentsburg
# City not Found...Skipping
# Processing Record 45 of Set 2 | marsh harbour
# City Found
# Processing Record 46 of Set 2 | gunnedah
# City Found
# Processing Record 47 of Set 2 | sechura
# City Found
# Processing Record 48 of Set 2 | ponta do sol
# City Found
# Processing Record 49 of Set 2 | grand river south east
# City not Found...Skipping
# Processing Record 50 of Set 2 | ancud
# City Found
# Processing Record 1 of Set 3 | fayaoue
# City Found
# Processing Record 2 of Set 3 | fairbanks
# City Found
# Processing Record 3 of Set 3 | krasnoselkup
# City Found
# Processing Record 4 of Set 3 | killybegs
# City Found
# Processing Record 5 of Set 3 | aras
# City Found
# Processing Record 6 of Set 3 | qaanaaq
# City Found
# Processing Record 7 of Set 3 | yamethin
# City Found
# Processing Record 8 of Set 3 | lorengau
# City Found
# Processing Record 9 of Set 3 | myitkyina
# City Found
# Processing Record 10 of Set 3 | saldanha
# City Found
# Processing Record 11 of Set 3 | cherskiy
# City Found
# Processing Record 12 of Set 3 | hanmer springs
# City Found
# Processing Record 13 of Set 3 | saleaula
# City not Found...Skipping
# Processing Record 14 of Set 3 | kuantan
# City Found
# Processing Record 15 of Set 3 | klyuchi
# City Found
# Processing Record 16 of Set 3 | sao filipe
# City Found
# Processing Record 17 of Set 3 | leningradskiy
# City Found
# Processing Record 18 of Set 3 | itigi
# City Found
# Processing Record 19 of Set 3 | caravelas
# City Found
# Processing Record 20 of Set 3 | yatou
# City Found
# Processing Record 21 of Set 3 | jamestown
# City Found
# Processing Record 22 of Set 3 | abbeville
# City Found
# Processing Record 23 of Set 3 | faridpur
# City Found
# Processing Record 24 of Set 3 | ugoofaaru
# City Found
# Processing Record 25 of Set 3 | necochea
# City Found
# Processing Record 26 of Set 3 | vallenar
# City Found
# Processing Record 27 of Set 3 | new norfolk
# City Found
# Processing Record 28 of Set 3 | illela
# City Found
# Processing Record 29 of Set 3 | safaga
# City Found
# Processing Record 30 of Set 3 | gazojak
# City Found
# Processing Record 31 of Set 3 | fuxin
# City Found
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not Found...Skipping
# Processing Record 33 of Set 3 | anadyr
# City Found
# Processing Record 34 of Set 3 | kapaa
# City Found
# Processing Record 35 of Set 3 | sept-iles
# City Found
# Processing Record 36 of Set 3 | jiangyou
# City Found
# Processing Record 37 of Set 3 | paamiut
# City Found
# Processing Record 38 of Set 3 | bereda
# City Found
# Processing Record 39 of Set 3 | sawakin
# City Found
# Processing Record 40 of Set 3 | roanoke
# City Found
# Processing Record 41 of Set 3 | shihezi
# City Found
# Processing Record 42 of Set 3 | pevek
# City Found
# Processing Record 43 of Set 3 | flinders
# City Found
# Processing Record 44 of Set 3 | agadir
# City Found
# Processing Record 45 of Set 3 | baijiantan
# City Found
# Processing Record 46 of Set 3 | marawi
# City Found
# Processing Record 47 of Set 3 | shenjiamen
# City Found
# Processing Record 48 of Set 3 | cuamba
# City Found
# Processing Record 49 of Set 3 | kudahuvadhoo
# City Found
# Processing Record 50 of Set 3 | falealupo
# City not Found...Skipping
# Processing Record 1 of Set 4 | chiang khong
# City Found
# Processing Record 2 of Set 4 | alyangula
# City Found
# Processing Record 3 of Set 4 | ixtapa
# City Found
# Processing Record 4 of Set 4 | zapadnaya dvina
# City Found
# Processing Record 5 of Set 4 | barahona
# City Found
# Processing Record 6 of Set 4 | mahebourg
# City Found
# Processing Record 7 of Set 4 | arraial do cabo
# City Found
# Processing Record 8 of Set 4 | manadhoo
# City Found
# Processing Record 9 of Set 4 | torrelavega
# City Found
# Processing Record 10 of Set 4 | lagoa
# City Found
# Processing Record 11 of Set 4 | longyearbyen
# City Found
# Processing Record 12 of Set 4 | port hardy
# City Found
# Processing Record 13 of Set 4 | chapleau
# City Found
# Processing Record 14 of Set 4 | grants
# City Found
# Processing Record 15 of Set 4 | pangoa
# City Found
# Processing Record 16 of Set 4 | mitsamiouli
# City Found
# Processing Record 17 of Set 4 | nobres
# City Found
# Processing Record 18 of Set 4 | saint-joseph
# City Found
# Processing Record 19 of Set 4 | beringovskiy
# City Found
# Processing Record 20 of Set 4 | torrevieja
# City Found
# Processing Record 21 of Set 4 | goderich
# City Found
# Processing Record 22 of Set 4 | vieux fort
# City Found
# Processing Record 23 of Set 4 | bousso
# City Found
# Processing Record 24 of Set 4 | hamilton
# City Found
# Processing Record 25 of Set 4 | san quintin
# City Found
# Processing Record 26 of Set 4 | hualmay
# City Found
# Processing Record 27 of Set 4 | lata
# City Found
# Processing Record 28 of Set 4 | vila franca do campo
# City Found
# Processing Record 29 of Set 4 | san patricio
# City Found
# Processing Record 30 of Set 4 | bathsheba
# City Found
# Processing Record 31 of Set 4 | umzimvubu
# City not Found...Skipping
# Processing Record 32 of Set 4 | najran
# City Found
# Processing Record 33 of Set 4 | matsusaka
# City Found
# Processing Record 34 of Set 4 | castrillon
# City Found
# Processing Record 35 of Set 4 | mount isa
# City Found
# Processing Record 36 of Set 4 | proletarskiy
# City Found
# Processing Record 37 of Set 4 | roald
# City Found
# Processing Record 38 of Set 4 | lompoc
# City Found
# Processing Record 39 of Set 4 | strelka
# City Found
# Processing Record 40 of Set 4 | kashin
# City Found
# Processing Record 41 of Set 4 | east london
# City Found
# Processing Record 42 of Set 4 | along
# City Found
# Processing Record 43 of Set 4 | san vicente
# City Found
# Processing Record 44 of Set 4 | avera
# City Found
# Processing Record 45 of Set 4 | kampot
# City Found
# Processing Record 46 of Set 4 | iqaluit
# City Found
# Processing Record 47 of Set 4 | dzilam gonzalez
# City Found
# Processing Record 48 of Set 4 | agirish
# City Found
# Processing Record 49 of Set 4 | rawson
# City Found
# Processing Record 50 of Set 4 | leshukonskoye
# City Found
# Processing Record 1 of Set 5 | dikson
# City Found
# Processing Record 2 of Set 5 | cumaribo
# City not Found...Skipping
# Processing Record 3 of Set 5 | khani
# City Found
# Processing Record 4 of Set 5 | butaritari
# City Found
# Processing Record 5 of Set 5 | mega
# City Found
# Processing Record 6 of Set 5 | berdigestyakh
# City Found
# Processing Record 7 of Set 5 | klaksvik
# City Found
# Processing Record 8 of Set 5 | cabedelo
# City Found
# Processing Record 9 of Set 5 | gorontalo
# City Found
# Processing Record 10 of Set 5 | bolivar
# City Found
# Processing Record 11 of Set 5 | saint-philippe
# City Found
# Processing Record 12 of Set 5 | hofn
# City Found
# Processing Record 13 of Set 5 | hasaki
# City Found
# Processing Record 14 of Set 5 | abnub
# City Found
# Processing Record 15 of Set 5 | haines junction
# City Found
# Processing Record 16 of Set 5 | quatre cocos
# City Found
# Processing Record 17 of Set 5 | nizhneyansk
# City not Found...Skipping
# Processing Record 18 of Set 5 | faya
# City Found
# Processing Record 19 of Set 5 | watsa
# City Found
# Processing Record 20 of Set 5 | atuona
# City Found
# Processing Record 21 of Set 5 | chapais
# City Found
# Processing Record 22 of Set 5 | tumannyy
# City not Found...Skipping
# Processing Record 23 of Set 5 | souillac
# City Found
# Processing Record 24 of Set 5 | kahului
# City Found
# Processing Record 25 of Set 5 | urzicuta
# City Found
# Processing Record 26 of Set 5 | horizontina
# City Found
# Processing Record 27 of Set 5 | hokitika
# City Found
# Processing Record 28 of Set 5 | nikolskoye
# City Found
# Processing Record 29 of Set 5 | baruun-urt
# City Found
# Processing Record 30 of Set 5 | puerto ayora
# City Found
# Processing Record 31 of Set 5 | vao
# City Found
# Processing Record 32 of Set 5 | tuatapere
# City Found
# Processing Record 33 of Set 5 | tuktoyaktuk
# City Found
# Processing Record 34 of Set 5 | lanzhou
# City Found
# Processing Record 35 of Set 5 | shizunai
# City Found
# Processing Record 36 of Set 5 | saint-pierre
# City Found
# Processing Record 37 of Set 5 | celendin
# City Found
# Processing Record 38 of Set 5 | trebisacce
# City Found
# Processing Record 39 of Set 5 | aksu
# City Found
# Processing Record 40 of Set 5 | bar harbor
# City Found
# Processing Record 41 of Set 5 | ormara
# City Found
# Processing Record 42 of Set 5 | halifax
# City Found
# Processing Record 43 of Set 5 | colares
# City Found
# Processing Record 44 of Set 5 | patiya
# City Found
# Processing Record 45 of Set 5 | bajil
# City Found
# Processing Record 46 of Set 5 | itarema
# City Found
# Processing Record 47 of Set 5 | esperance
# City Found
# Processing Record 48 of Set 5 | lahaina
# City Found
# Processing Record 49 of Set 5 | hailar
# City Found
# Processing Record 50 of Set 5 | caiaponia
# City Found
# Processing Record 1 of Set 6 | kavaratti
# City Found
# Processing Record 2 of Set 6 | erenhot
# City Found
# Processing Record 3 of Set 6 | kurilsk
# City Found
# Processing Record 4 of Set 6 | merritt island
# City Found
# Processing Record 5 of Set 6 | kyra
# City Found
# Processing Record 6 of Set 6 | sadon
# City Found
# Processing Record 7 of Set 6 | aracoiaba
# City Found
# Processing Record 8 of Set 6 | richards bay
# City Found
# Processing Record 9 of Set 6 | san carlos de bariloche
# City Found
# Processing Record 10 of Set 6 | paciran
# City Found
# Processing Record 11 of Set 6 | balikpapan
# City Found
# Processing Record 12 of Set 6 | thyboron
# City Found
# Processing Record 13 of Set 6 | faanui
# City Found
# Processing Record 14 of Set 6 | srednekolymsk
# City Found
# Processing Record 15 of Set 6 | kupang
# City Found
# Processing Record 16 of Set 6 | ijaki
# City not Found...Skipping
# Processing Record 17 of Set 6 | severo-kurilsk
# City Found
# Processing Record 18 of Set 6 | bol
# City Found
# Processing Record 19 of Set 6 | shibarghan
# City not Found...Skipping
# Processing Record 20 of Set 6 | lincoln
# City Found
# Processing Record 21 of Set 6 | mackay
# City Found
# Processing Record 22 of Set 6 | phan rang
# City not Found...Skipping
# Processing Record 23 of Set 6 | calvinia
# City Found
# Processing Record 24 of Set 6 | tara
# City Found
# Processing Record 25 of Set 6 | chikoy
# City not Found...Skipping
# Processing Record 26 of Set 6 | port-gentil
# City Found
# Processing Record 27 of Set 6 | bengkulu
# City Found
# Processing Record 28 of Set 6 | gafanha da encarnacao
# City Found
# Processing Record 29 of Set 6 | santiago del estero
# City Found
# Processing Record 30 of Set 6 | tabou
# City Found
# Processing Record 31 of Set 6 | estepona
# City Found
# Processing Record 32 of Set 6 | tabat
# City Found
# Processing Record 33 of Set 6 | lebedinyy
# City Found
# Processing Record 34 of Set 6 | hay river
# City Found
# Processing Record 35 of Set 6 | peace river
# City Found
# Processing Record 36 of Set 6 | labuhan
# City Found
# Processing Record 37 of Set 6 | qiongshan
# City Found
# Processing Record 38 of Set 6 | mabaruma
# City Found
# Processing Record 39 of Set 6 | kaliua
# City Found
# Processing Record 40 of Set 6 | katobu
# City Found
# Processing Record 41 of Set 6 | nurota
# City Found
# Processing Record 42 of Set 6 | port macquarie
# City Found
# Processing Record 43 of Set 6 | victoria
# City Found
# Processing Record 44 of Set 6 | camacha
# City Found
# Processing Record 45 of Set 6 | zyryanka
# City Found
# Processing Record 46 of Set 6 | tokmak
# City Found
# Processing Record 47 of Set 6 | narsaq
# City Found
# Processing Record 48 of Set 6 | port blair
# City Found
# Processing Record 49 of Set 6 | broome
# City Found
# Processing Record 50 of Set 6 | swan hill
# City Found
# Processing Record 1 of Set 7 | sibolga
# City Found
# Processing Record 2 of Set 7 | hobyo
# City Found
# Processing Record 3 of Set 7 | kamenskoye
# City not Found...Skipping
# Processing Record 4 of Set 7 | ribeira grande
# City Found
# Processing Record 5 of Set 7 | karratha
# City Found
# Processing Record 6 of Set 7 | ambilobe
# City Found
# Processing Record 7 of Set 7 | aklavik
# City Found
# Processing Record 8 of Set 7 | emerald
# City Found
# Processing Record 9 of Set 7 | mae hong son
# City Found
# Processing Record 10 of Set 7 | tilichiki
# City Found
# Processing Record 11 of Set 7 | acapulco
# City Found
# Processing Record 12 of Set 7 | usinsk
# City Found
# Processing Record 13 of Set 7 | bambous virieux
# City Found
# Processing Record 14 of Set 7 | benguela
# City Found
# Processing Record 15 of Set 7 | asosa
# City Found
# Processing Record 16 of Set 7 | lusambo
# City Found
# Processing Record 17 of Set 7 | ontario
# City Found
# Processing Record 18 of Set 7 | yumen
# City Found
# Processing Record 19 of Set 7 | wanning
# City Found
# Processing Record 20 of Set 7 | mount gambier
# City Found
# Processing Record 21 of Set 7 | urumqi
# City Found
# Processing Record 22 of Set 7 | samalaeulu
# City not Found...Skipping
# Processing Record 23 of Set 7 | sisimiut
# City Found
# Processing Record 24 of Set 7 | placido de castro
# City Found
# Processing Record 25 of Set 7 | rio grande
# City Found
# Processing Record 26 of Set 7 | alofi
# City Found
# Processing Record 27 of Set 7 | galle
# City Found
# Processing Record 28 of Set 7 | marcona
# City not Found...Skipping
# Processing Record 29 of Set 7 | coquimbo
# City Found
# Processing Record 30 of Set 7 | nome
# City Found
# Processing Record 31 of Set 7 | ust-uda
# City Found
# Processing Record 32 of Set 7 | paradwip
# City not Found...Skipping
# Processing Record 33 of Set 7 | mayo
# City Found
# Processing Record 34 of Set 7 | belaya gora
# City Found
# Processing Record 35 of Set 7 | opportunity
# City Found
# Processing Record 36 of Set 7 | pokhara
# City Found
# Processing Record 37 of Set 7 | palabuhanratu
# City not Found...Skipping
# Processing Record 38 of Set 7 | wahran
# City not Found...Skipping
# Processing Record 39 of Set 7 | aguimes
# City Found
# Processing Record 40 of Set 7 | saskylakh
# City Found
# Processing Record 41 of Set 7 | damavand
# City Found
# Processing Record 42 of Set 7 | tezu
# City Found
# Processing Record 43 of Set 7 | grand baie
# City Found
# Processing Record 44 of Set 7 | clyde river
# City Found
# Processing Record 45 of Set 7 | mys shmidta
# City not Found...Skipping
# Processing Record 46 of Set 7 | lebu
# City Found
# Processing Record 47 of Set 7 | severo-yeniseyskiy
# City Found
# Processing Record 48 of Set 7 | andevoranto
# City not Found...Skipping
# Processing Record 49 of Set 7 | port lincoln
# City Found
# Processing Record 50 of Set 7 | flagstaff
# City Found
# Processing Record 1 of Set 8 | bada
# City Found
# Processing Record 2 of Set 8 | wattegama
# City Found
# Processing Record 3 of Set 8 | romny
# City Found
# Processing Record 4 of Set 8 | lufilufi
# City Found
# Processing Record 5 of Set 8 | noshiro
# City Found
# Processing Record 6 of Set 8 | presidente medici
# City Found
# Processing Record 7 of Set 8 | saint-pacome
# City not Found...Skipping
# Processing Record 8 of Set 8 | kuala terengganu
# City Found
# Processing Record 9 of Set 8 | nova olimpia
# City Found
# Processing Record 10 of Set 8 | namibe
# City Found
# Processing Record 11 of Set 8 | natal
# City Found
# Processing Record 12 of Set 8 | kaitangata
# City Found
# Processing Record 13 of Set 8 | sistranda
# City Found
# Processing Record 14 of Set 8 | verkhoyansk
# City Found
# Processing Record 15 of Set 8 | chabahar
# City Found
# Processing Record 16 of Set 8 | dwarka
# City Found
# Processing Record 17 of Set 8 | norman wells
# City Found
# Processing Record 18 of Set 8 | sicamous
# City Found
# Processing Record 19 of Set 8 | niedernhausen
# City Found
# Processing Record 20 of Set 8 | zhigansk
# City Found
# Processing Record 21 of Set 8 | gazanjyk
# City Found
# Processing Record 22 of Set 8 | vestmanna
# City Found
# Processing Record 23 of Set 8 | hirara
# City Found
# Processing Record 24 of Set 8 | choix
# City Found
# Processing Record 25 of Set 8 | luderitz
# City Found
# Processing Record 26 of Set 8 | sayama
# City Found
# Processing Record 27 of Set 8 | watertown
# City Found
# Processing Record 28 of Set 8 | kavieng
# City Found
# Processing Record 29 of Set 8 | kruisfontein
# City Found
# Processing Record 30 of Set 8 | chimbote
# City Found
# Processing Record 31 of Set 8 | zhongshu
# City Found
# Processing Record 32 of Set 8 | vanavara
# City Found
# Processing Record 33 of Set 8 | inta
# City Found
# Processing Record 34 of Set 8 | belgrade
# City Found
# Processing Record 35 of Set 8 | pecel
# City Found
# Processing Record 36 of Set 8 | salalah
# City Found
# Processing Record 37 of Set 8 | lircay
# City Found
# Processing Record 38 of Set 8 | middelburg
# City Found
# Processing Record 39 of Set 8 | evensk
# City Found
# Processing Record 40 of Set 8 | kabo
# City Found
# Processing Record 41 of Set 8 | anaco
# City Found
# Processing Record 42 of Set 8 | georgetown
# City Found
# Processing Record 43 of Set 8 | garmsar
# City Found
# Processing Record 44 of Set 8 | sri aman
# City Found
# Processing Record 45 of Set 8 | mozarlandia
# City Found
# Processing Record 46 of Set 8 | colomi
# City Found
# Processing Record 47 of Set 8 | katsuura
# City Found
# Processing Record 48 of Set 8 | matamoros
# City Found
# Processing Record 49 of Set 8 | bure
# City Found
# Processing Record 50 of Set 8 | mali
# City Found
# Processing Record 1 of Set 9 | los llanos de aridane
# City Found
# Processing Record 2 of Set 9 | albolote
# City Found
# Processing Record 3 of Set 9 | burnie
# City Found
# Processing Record 4 of Set 9 | dublin
# City Found
# Processing Record 5 of Set 9 | carnarvon
# City Found
# Processing Record 6 of Set 9 | ilo
# City Found
# Processing Record 7 of Set 9 | xai-xai
# City Found
# Processing Record 8 of Set 9 | atar
# City Found
# Processing Record 9 of Set 9 | san cristobal
# City Found
# Processing Record 10 of Set 9 | mmabatho
# City Found
# Processing Record 11 of Set 9 | itupeva
# City Found
# Processing Record 12 of Set 9 | sao jose da coroa grande
# City Found
# Processing Record 13 of Set 9 | mandurah
# City Found
# Processing Record 14 of Set 9 | stanghelle
# City Found
# Processing Record 15 of Set 9 | neuquen
# City Found
# Processing Record 16 of Set 9 | puerto narino
# City Found
# Processing Record 17 of Set 9 | provideniya
# City Found
# Processing Record 18 of Set 9 | yanan
# City not Found...Skipping
# Processing Record 19 of Set 9 | orlik
# City Found
# Processing Record 20 of Set 9 | mbarara
# City Found
# Processing Record 21 of Set 9 | bonthe
# City Found
# Processing Record 22 of Set 9 | iberia
# City Found
# Processing Record 23 of Set 9 | taoudenni
# City Found
# Processing Record 24 of Set 9 | shiraz
# City Found
# Processing Record 25 of Set 9 | general roca
# City Found
# Processing Record 26 of Set 9 | asfi
# City Found
# Processing Record 27 of Set 9 | birjand
# City Found
# Processing Record 28 of Set 9 | manica
# City Found
# Processing Record 29 of Set 9 | bid
# City not Found...Skipping
# Processing Record 30 of Set 9 | dujuma
# City not Found...Skipping
# Processing Record 31 of Set 9 | harlingen
# City Found
# Processing Record 32 of Set 9 | mamontovo
# City Found
# Processing Record 33 of Set 9 | peniche
# City Found
# Processing Record 34 of Set 9 | santa cruz
# City Found
# Processing Record 35 of Set 9 | malwan
# City not Found...Skipping
# Processing Record 36 of Set 9 | kisiwani
# City Found
# Processing Record 37 of Set 9 | ballitoville
# City Found
# Processing Record 38 of Set 9 | alvdal
# City Found
# Processing Record 39 of Set 9 | lolua
# City not Found...Skipping
# Processing Record 40 of Set 9 | constitucion
# City Found
# Processing Record 41 of Set 9 | havoysund
# City Found
# Processing Record 42 of Set 9 | codrington
# City Found
# Processing Record 43 of Set 9 | isangel
# City Found
# Processing Record 44 of Set 9 | dingle
# City Found
# Processing Record 45 of Set 9 | mareeba
# City Found
# Processing Record 46 of Set 9 | praya
# City Found
# Processing Record 47 of Set 9 | gigmoto
# City Found
# Processing Record 48 of Set 9 | vaitupu
# City not Found...Skipping
# Processing Record 49 of Set 9 | high rock
# City Found
# Processing Record 50 of Set 9 | ostrovnoy
# City Found
# Processing Record 1 of Set 10 | oussouye
# City Found
# Processing Record 2 of Set 10 | strezhevoy
# City Found
# Processing Record 3 of Set 10 | hambantota
# City Found
# Processing Record 4 of Set 10 | coihaique
# City Found
# Processing Record 5 of Set 10 | abha
# City Found
# Processing Record 6 of Set 10 | college
# City Found
# Processing Record 7 of Set 10 | mahajanga
# City Found
# Processing Record 8 of Set 10 | bontang
# City Found
# Processing Record 9 of Set 10 | malibu
# City Found
# Processing Record 10 of Set 10 | devrek
# City Found
# Processing Record 11 of Set 10 | walvis bay
# City Found
# Processing Record 12 of Set 10 | houma
# City Found
# Processing Record 13 of Set 10 | tucson
# City Found
# Processing Record 14 of Set 10 | viligili
# City not Found...Skipping
# Processing Record 15 of Set 10 | esmeraldas
# City Found
# Processing Record 16 of Set 10 | naze
# City Found
# Processing Record 17 of Set 10 | tosya
# City Found
# Processing Record 18 of Set 10 | margate
# City Found
# Processing Record 19 of Set 10 | pyapon
# City Found
# Processing Record 20 of Set 10 | chifeng
# City Found
# Processing Record 21 of Set 10 | nara
# City Found
# Processing Record 22 of Set 10 | olafsvik
# City Found
# Processing Record 23 of Set 10 | tadepallegudem
# City Found
# Processing Record 24 of Set 10 | iquitos
# City Found
# Processing Record 25 of Set 10 | sinjar
# City Found
# Processing Record 26 of Set 10 | golden rock
# City not Found...Skipping
# Processing Record 27 of Set 10 | crotone
# City Found
# Processing Record 28 of Set 10 | wilmington
# City Found
# Processing Record 29 of Set 10 | mazagao
# City Found
# Processing Record 30 of Set 10 | zhangye
# City Found
# Processing Record 31 of Set 10 | dongsheng
# City Found
# Processing Record 32 of Set 10 | nyuksenitsa
# City Found
# Processing Record 33 of Set 10 | bestobe
# City Found
# Processing Record 34 of Set 10 | keetmanshoop
# City Found
# Processing Record 35 of Set 10 | le vauclin
# City Found
# Processing Record 36 of Set 10 | champerico
# City Found
# Processing Record 37 of Set 10 | marystown
# City Found
# Processing Record 38 of Set 10 | conceicao da barra
# City Found
# Processing Record 39 of Set 10 | sitarganj
# City Found
# Processing Record 40 of Set 10 | vereeniging
# City Found
# Processing Record 41 of Set 10 | sterling
# City Found
# Processing Record 42 of Set 10 | hami
# City Found
# Processing Record 43 of Set 10 | kloulklubed
# City Found
# Processing Record 44 of Set 10 | nohar
# City Found
# Processing Record 45 of Set 10 | gunjur
# City Found
# Processing Record 46 of Set 10 | tuggurt
# City not Found...Skipping
# Processing Record 47 of Set 10 | miles city
# City Found
# Processing Record 48 of Set 10 | shelabolikha
# City Found
# Processing Record 49 of Set 10 | antsohihy
# City Found
# Processing Record 50 of Set 10 | yidu
# City Found
# Processing Record 1 of Set 11 | maceio
# City Found
# Processing Record 2 of Set 11 | amapa
# City Found
# Processing Record 3 of Set 11 | warqla
# City not Found...Skipping
# Processing Record 4 of Set 11 | beyneu
# City Found
# Processing Record 5 of Set 11 | nanortalik
# City Found
# Processing Record 6 of Set 11 | port augusta
# City Found
# Processing Record 7 of Set 11 | simbahan
# City Found
# Processing Record 8 of Set 11 | lysva
# City Found
# Processing Record 9 of Set 11 | manta
# City Found
# Processing Record 10 of Set 11 | yar-sale
# City Found
# Processing Record 11 of Set 11 | moose factory
# City Found
# Processing Record 12 of Set 11 | berlevag
# City Found
# Processing Record 13 of Set 11 | zavyalovo
# City Found
# Processing Record 14 of Set 11 | auce
# City Found
# Processing Record 15 of Set 11 | pontarlier
# City Found
# Processing Record 16 of Set 11 | buchanan
# City Found
# Processing Record 17 of Set 11 | fare
# City Found
# Processing Record 18 of Set 11 | caohai
# City Found
# Processing Record 19 of Set 11 | gorom-gorom
# City Found
# Processing Record 20 of Set 11 | teguldet
# City Found
# Processing Record 21 of Set 11 | aswan
# City Found
# Processing Record 22 of Set 11 | sussex
# City Found
# Processing Record 23 of Set 11 | tonj
# City Found
# Processing Record 24 of Set 11 | lokosovo
# City Found
# Processing Record 25 of Set 11 | mehamn
# City Found
# Processing Record 26 of Set 11 | ust-omchug
# City Found
# Processing Record 27 of Set 11 | tulghes
# City Found
# Processing Record 28 of Set 11 | omboue
# City Found
# Processing Record 29 of Set 11 | cidreira
# City Found
# Processing Record 30 of Set 11 | benton harbor
# City Found
# Processing Record 31 of Set 11 | abalak
# City Found
# Processing Record 32 of Set 11 | pangnirtung
# City Found
# Processing Record 33 of Set 11 | la colorada
# City Found
# Processing Record 34 of Set 11 | kamenka
# City Found
# Processing Record 35 of Set 11 | namatanai
# City Found
# Processing Record 36 of Set 11 | dunedin
# City Found
# Processing Record 37 of Set 11 | heihe
# City Found
# Processing Record 38 of Set 11 | son la
# City Found
# Processing Record 39 of Set 11 | komsomolskiy
# City Found
# Processing Record 40 of Set 11 | teya
# City Found
# Processing Record 41 of Set 11 | montauban
# City Found
# Processing Record 42 of Set 11 | wolfenbuttel
# City Found
# Processing Record 43 of Set 11 | nehe
# City Found
# Processing Record 44 of Set 11 | opuwo
# City Found
# Processing Record 45 of Set 11 | husavik
# City Found
# Processing Record 46 of Set 11 | puerto quijarro
# City Found
# Processing Record 47 of Set 11 | waipawa
# City Found
# Processing Record 48 of Set 11 | contamana
# City Found
# Processing Record 49 of Set 11 | salinopolis
# City Found
# Processing Record 50 of Set 11 | mackenzie
# City Found
# Processing Record 1 of Set 12 | toliary
# City not Found...Skipping
# Processing Record 2 of Set 12 | minden
# City Found
# Processing Record 3 of Set 12 | narkevychi
# City Found
# Processing Record 4 of Set 12 | deputatskiy
# City Found
# Processing Record 5 of Set 12 | willowmore
# City Found
# Processing Record 6 of Set 12 | chara
# City Found
# Processing Record 7 of Set 12 | grahamstown
# City Found
# Processing Record 8 of Set 12 | bosaso
# City Found
# Processing Record 9 of Set 12 | nador
# City Found
# Processing Record 10 of Set 12 | tarudant
# City not Found...Skipping
# Processing Record 11 of Set 12 | deh rawud
# City not Found...Skipping
# Processing Record 12 of Set 12 | glendive
# City Found
# Processing Record 13 of Set 12 | bonoua
# City Found
# Processing Record 14 of Set 12 | cockburn town
# City Found
# Processing Record 15 of Set 12 | yerbogachen
# City Found
# Processing Record 16 of Set 12 | waingapu
# City Found
# Processing Record 17 of Set 12 | karaton
# City Found
# Processing Record 18 of Set 12 | guozhen
# City Found
# Processing Record 19 of Set 12 | castro daire
# City Found
# Processing Record 20 of Set 12 | scarborough
# City Found
# Processing Record 21 of Set 12 | chitipa
# City Found
# Processing Record 22 of Set 12 | broken hill
# City Found
# Processing Record 23 of Set 12 | louisbourg
# City not Found...Skipping
# Processing Record 24 of Set 12 | talnakh
# City Found
# Processing Record 25 of Set 12 | amalapuram
# City Found
# Processing Record 26 of Set 12 | takoradi
# City Found
# Processing Record 27 of Set 12 | mugur-aksy
# City Found
# Processing Record 28 of Set 12 | lublin
# City Found
# Processing Record 29 of Set 12 | morinville
# City Found
# Processing Record 30 of Set 12 | san luis
# City Found
# Processing Record 31 of Set 12 | yueyang
# City Found
# Processing Record 32 of Set 12 | sandwick
# City Found
# Processing Record 33 of Set 12 | te anau
# City Found
# Processing Record 34 of Set 12 | touros
# City Found
# Processing Record 35 of Set 12 | boueni
# City Found
# Processing Record 36 of Set 12 | grajau
# City Found
# Processing Record 37 of Set 12 | pauini
# City Found
# Processing Record 38 of Set 12 | dondo
# City Found
# Processing Record 39 of Set 12 | san jose
# City Found
# Processing Record 40 of Set 12 | boca do acre
# City Found
# Processing Record 41 of Set 12 | constanza
# City Found
# Processing Record 42 of Set 12 | moberly
# City Found
# Processing Record 43 of Set 12 | goya
# City Found
# Processing Record 44 of Set 12 | sorvag
# City not Found...Skipping
# Processing Record 45 of Set 12 | bandipur
# City Found
# Processing Record 46 of Set 12 | funtua
# City Found
# Processing Record 47 of Set 12 | kadykchan
# City not Found...Skipping
# Processing Record 48 of Set 12 | nantucket
# City Found
# Processing Record 49 of Set 12 | sami
# City Found
# Processing Record 50 of Set 12 | jambi
# City Found
# Processing Record 1 of Set 13 | villazon
# City Found
# Processing Record 2 of Set 13 | sioux lookout
# City Found
# Processing Record 3 of Set 13 | khromtau
# City Found
# Processing Record 4 of Set 13 | felipe carrillo puerto
# City Found
# Processing Record 5 of Set 13 | shimanovsk
# City Found
# Processing Record 6 of Set 13 | mogadishu
# City Found
# Processing Record 7 of Set 13 | ust-maya
# City Found
# Processing Record 8 of Set 13 | nishihara
# City Found
# Processing Record 9 of Set 13 | assela
# City not Found...Skipping
# Processing Record 10 of Set 13 | utiroa
# City not Found...Skipping
# Processing Record 11 of Set 13 | carutapera
# City Found
# Processing Record 12 of Set 13 | okhotsk
# City Found
# Processing Record 13 of Set 13 | havelock
# City Found
# Processing Record 14 of Set 13 | roblin
# City Found
# Processing Record 15 of Set 13 | floro
# City Found
# Processing Record 16 of Set 13 | marau
# City Found
# Processing Record 17 of Set 13 | takab
# City Found
# Processing Record 18 of Set 13 | axim
# City Found
# Processing Record 19 of Set 13 | manaure
# City Found
# Processing Record 20 of Set 13 | san carlos
# City Found
# Processing Record 21 of Set 13 | omaruru
# City Found
# Processing Record 22 of Set 13 | tigil
# City Found
# Processing Record 23 of Set 13 | marana
# City Found
# Processing Record 24 of Set 13 | christchurch
# City Found
# Processing Record 25 of Set 13 | muktagachha
# City not Found...Skipping
# Processing Record 26 of Set 13 | oranjemund
# City Found
# Processing Record 27 of Set 13 | isla mujeres
# City Found
# Processing Record 28 of Set 13 | lavrentiya
# City Found
# Processing Record 29 of Set 13 | sabang
# City Found
# Processing Record 30 of Set 13 | rudnogorsk
# City Found
# Processing Record 31 of Set 13 | temaraia
# City not Found...Skipping
# Processing Record 32 of Set 13 | maxixe
# City Found
# Processing Record 33 of Set 13 | ballarat
# City Found
# Processing Record 34 of Set 13 | rungata
# City not Found...Skipping
# Processing Record 35 of Set 13 | jiayuguan
# City Found
# Processing Record 36 of Set 13 | bonavista
# City Found
# Processing Record 37 of Set 13 | nhulunbuy
# City Found
# Processing Record 38 of Set 13 | bujumbura
# City Found
# Processing Record 39 of Set 13 | balabac
# City Found
# Processing Record 40 of Set 13 | comodoro rivadavia
# City Found
# Processing Record 41 of Set 13 | mahibadhoo
# City Found
# Processing Record 42 of Set 13 | murgab
# City Found
# Processing Record 43 of Set 13 | basyanovskiy
# City not Found...Skipping
# Processing Record 44 of Set 13 | berberati
# City Found
# Processing Record 45 of Set 13 | cap malheureux
# City Found
# Processing Record 46 of Set 13 | nikolayevsk-na-amure
# City Found
# Processing Record 47 of Set 13 | nemuro
# City Found
# Processing Record 48 of Set 13 | sungaipenuh
# City Found
# Processing Record 49 of Set 13 | geraldton
# City Found
# Processing Record 50 of Set 13 | long beach
# City Found
# Processing Record 1 of Set 14 | dalvik
# City Found
# Processing Record 2 of Set 14 | tiszafoldvar
# City Found
# Processing Record 3 of Set 14 | port hedland
# City Found
# Processing Record 4 of Set 14 | ulaanbaatar
# City Found
# Processing Record 5 of Set 14 | cayenne
# City Found
# Processing Record 6 of Set 14 | kayerkan
# City Found
# Processing Record 7 of Set 14 | dali
# City Found
# Processing Record 8 of Set 14 | shibetsu
# City Found
# Processing Record 9 of Set 14 | skala
# City Found
# Processing Record 10 of Set 14 | uvalde
# City Found
# Processing Record 11 of Set 14 | fortuna
# City Found
# Processing Record 12 of Set 14 | linfen
# City Found
# Processing Record 13 of Set 14 | teguise
# City Found
# Processing Record 14 of Set 14 | nyurba
# City Found
# Processing Record 15 of Set 14 | aripuana
# City Found
# Processing Record 16 of Set 14 | aldan
# City Found
# Processing Record 17 of Set 14 | kidal
# City Found
# Processing Record 18 of Set 14 | dordrecht
# City Found
# Processing Record 19 of Set 14 | krylovskaya
# City Found
# Processing Record 20 of Set 14 | khorixas
# City Found
# Processing Record 21 of Set 14 | bako
# City Found
# Processing Record 22 of Set 14 | valer
# City Found
# Processing Record 23 of Set 14 | darhan
# City Found
# Processing Record 24 of Set 14 | paldiski
# City Found
# Processing Record 25 of Set 14 | dukat
# City Found
# Processing Record 26 of Set 14 | bossembele
# City not Found...Skipping
# Processing Record 27 of Set 14 | bahia blanca
# City Found
# Processing Record 28 of Set 14 | laguna
# City Found
# Processing Record 29 of Set 14 | coahuayana
# City Found
# Processing Record 30 of Set 14 | sao miguel do araguaia
# City Found
# Processing Record 31 of Set 14 | atsiki
# City not Found...Skipping
# Processing Record 32 of Set 14 | tabiauea
# City not Found...Skipping
# Processing Record 33 of Set 14 | ordu
# City Found
# Processing Record 34 of Set 14 | spencer
# City Found
# Processing Record 35 of Set 14 | kozan
# City Found
# Processing Record 36 of Set 14 | lasa
# City Found
# Processing Record 37 of Set 14 | chernaya kholunitsa
# City Found
# Processing Record 38 of Set 14 | pointe michel
# City Found
# Processing Record 39 of Set 14 | la libertad
# City Found
# Processing Record 40 of Set 14 | bollnas
# City Found
# Processing Record 41 of Set 14 | korem
# City Found
# Processing Record 42 of Set 14 | sentyabrskiy
# City not Found...Skipping
# Processing Record 43 of Set 14 | la ronge
# City Found
# Processing Record 44 of Set 14 | puerto varas
# City Found
# Processing Record 45 of Set 14 | golden
# City Found
# Processing Record 46 of Set 14 | mayor pablo lagerenza
# City Found
# Processing Record 47 of Set 14 | guabito
# City Found
# Processing Record 48 of Set 14 | rakiv lis
# City Found
# Processing Record 49 of Set 14 | muravlenko
# City Found
# Processing Record 50 of Set 14 | shimoda
# City Found
# Processing Record 1 of Set 15 | piqua
# City Found
# Processing Record 2 of Set 15 | coyah
# City Found
# Processing Record 3 of Set 15 | goundam
# City Found
# Processing Record 4 of Set 15 | bambanglipuro
# City Found
# Processing Record 5 of Set 15 | kijang
# City Found
# Processing Record 6 of Set 15 | hihifo
# City not Found...Skipping
# Processing Record 7 of Set 15 | gualaquiza
# City Found
# Processing Record 8 of Set 15 | jian
# City Found
# Processing Record 9 of Set 15 | caldwell
# City Found
# Processing Record 10 of Set 15 | tarko-sale
# City Found
# Processing Record 11 of Set 15 | juneau
# City Found
# Processing Record 12 of Set 15 | juifang
# City not Found...Skipping
# Processing Record 13 of Set 15 | gari
# City Found
# Processing Record 14 of Set 15 | marang
# City Found
# Processing Record 15 of Set 15 | shahganj
# City Found
# Processing Record 16 of Set 15 | chiredzi
# City Found
# Processing Record 17 of Set 15 | enshi
# City Found
# Processing Record 18 of Set 15 | pendleton
# City Found
# Processing Record 19 of Set 15 | svetlyy
# City Found
# Processing Record 20 of Set 15 | north battleford
# City Found
# Processing Record 21 of Set 15 | odienne
# City Found
# Processing Record 22 of Set 15 | uruzgan
# City Found
# Processing Record 23 of Set 15 | samarinda
# City Found
# Processing Record 24 of Set 15 | paris
# City Found
# Processing Record 25 of Set 15 | borogontsy
# City Found
# Processing Record 26 of Set 15 | aberdeen
# City Found
# Processing Record 27 of Set 15 | machali
# City Found
# Processing Record 28 of Set 15 | weiser
# City Found
# Processing Record 29 of Set 15 | phek
# City Found
# Processing Record 30 of Set 15 | russell
# City Found
# Processing Record 31 of Set 15 | chubbuck
# City Found
# Processing Record 32 of Set 15 | el rosario
# City Found
# Processing Record 33 of Set 15 | timra
# City Found
# Processing Record 34 of Set 15 | vozhega
# City Found
# Processing Record 35 of Set 15 | pizarro
# City Found
# Processing Record 36 of Set 15 | galiwinku
# City not Found...Skipping
# Processing Record 37 of Set 15 | marsa matruh
# City Found
# Processing Record 38 of Set 15 | jiaozhou
# City Found
# Processing Record 39 of Set 15 | qingquan
# City Found
# Processing Record 40 of Set 15 | chicama
# City Found
# Processing Record 41 of Set 15 | kaeo
# City Found
# Processing Record 42 of Set 15 | sabha
# City Found
# Processing Record 43 of Set 15 | dalianwan
# City Found
# Processing Record 44 of Set 15 | preobrazheniye
# City Found
# Processing Record 45 of Set 15 | santarem
# City Found
# Processing Record 46 of Set 15 | velsk
# City Found
# Processing Record 47 of Set 15 | neiafu
# City Found
# Processing Record 48 of Set 15 | maneadero
# City Found
# Processing Record 49 of Set 15 | buala
# City Found
# Processing Record 50 of Set 15 | half moon bay
# City Found
# Processing Record 1 of Set 16 | rongcheng
# City Found
# Processing Record 2 of Set 16 | agde
# City Found
# Processing Record 3 of Set 16 | dicabisagan
# City Found
# Processing Record 4 of Set 16 | jonkoping
# City Found
# Processing Record 5 of Set 16 | maloshuyka
# City not Found...Skipping
# Processing Record 6 of Set 16 | shishou
# City Found
# Processing Record 7 of Set 16 | smithers
# City Found
# Processing Record 8 of Set 16 | prainha
# City Found
# Processing Record 9 of Set 16 | atbasar
# City Found
# Processing Record 10 of Set 16 | ginda
# City Found
# Processing Record 11 of Set 16 | labutta
# City not Found...Skipping
# Processing Record 12 of Set 16 | ihlow
# City Found
# Processing Record 13 of Set 16 | lethem
# City Found
# Data Retrieval Complete

# %%
len(city_data)
# Out:
# 664

# %%
# created dataframe from city data
weather_df = pd.DataFrame(city_data)

weather_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hobart -42.8794  147.3294     46.26        69          40
# 1           Boende  -0.2167   20.8667     68.43        99          83
# 2            Vaini -21.2000 -175.2000     80.76        74          20
# 3        Caravelas -17.7125  -39.2481     69.84        77           8
# 4          Rikitea -23.1203 -134.9692     73.13        73           3
# 5      Port Alfred -33.5906   26.8910     56.17        92          99
# 6    Prince Rupert  54.3161 -130.3201     62.69        70           0
# 7  Minervino Murge  41.0843   16.0784     64.24        69          20
# 8           Castro -24.7911  -50.0119     54.82        98          98
# 9            Kapaa  22.0752 -159.3190     84.18        78         100
#
#    Wind Speed Country Current Description
# 0       12.66      AU    scattered clouds
# 1        1.86      CD       broken clouds
# 2        8.05      TO          few clouds
# 3        3.98      BR           clear sky
# 4        5.41      PF           clear sky
# 5       15.88      ZA          light rain
# 6        8.05      CA           clear sky
# 7        8.99      IT          few clouds
# 8        7.65      BR     overcast clouds
# 9        3.44      US          light rain

# %%
# rearrange Dataframe

column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Current Description']
weather_df = weather_df[column_order]
weather_df.sample(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 452  Komsomolskiy      UZ  40.4272   71.7189     63.32        48          63
# 178        Kozhva      RU  65.1073   57.0459     42.60        97          99
# 651          Tete      MZ -16.1564   33.5867     73.80        45           0
# 308     Tchollire      CM   8.4022   14.1698     70.90        94         100
# 217        Vanimo      PG  -2.6741  141.3028     83.57        67          97
# 18      Saskylakh      RU  71.9167  114.0833     33.78        80          90
# 95         Llanes      ES  43.4198   -4.7549     72.97        67          69
# 184       Gobabis      NA -22.4500   18.9667     64.92        14           0
# 324       Husavik      IS  66.0449  -17.3389     47.34        94         100
# 87         Hailey      US  43.5196 -114.3153     86.88        24           0
#
#     Current Description
# 452       broken clouds
# 178     overcast clouds
# 651           clear sky
# 308     overcast clouds
# 217     overcast clouds
# 18      overcast clouds
# 95        broken clouds
# 184           clear sky
# 324     overcast clouds
# 87                smoke

# %%
# export dataframe as csv
# create output file
output_data_file = 'WeatherPy_Database.csv'

# export dataframe to file
weather_df.to_csv(output_data_file, index_label='City_ID')
